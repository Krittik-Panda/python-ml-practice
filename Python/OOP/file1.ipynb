# %% [markdown]
# # in python everything is an object

# %% [markdown]
# ### class is a blue print of how object of that class behave

# %%
c = 90
type(c)
# Out:
# int

# %%
l = [3,'y',6,7]
print(type(l))
l.append("k")
print(l)
# Out:
# <class 'list'>
# [3, 'y', 6, 7, 'k']

# %% [markdown]
# ### l is a list datatype and an object of list class ..and append is a function that was defined in the list class and only list's class object l can access it

# %% [markdown]
# ### class name always in pascle case ( class IAmTheBoy) and the function are always in snake case ( I_Am_The_Boy())

# %% [markdown]
# ### how to create object
# if MySports is a class then golf is an object to make golf object
# golf = MySports()
#
# eg{  L = list() --> list class object, but we use L =[] , because its a build in class so we can use object literal to easily create the object   }

# %%
L = list()
L.append(7)
print(L)
# Out:
# [7]

# %% [markdown]
# ### methodes are the special function that used to inside the class
