# %% [markdown]
# ### Instance variable is variable whose value is different for each object of the same class

# %%
class ATM:
    def __init__(self):
        self.pin = ""
        self.balance = 0
        self.menu()
      
    def menu(self):        
        choice = int(input("""
            Enter the option no : 
            1) Set pin
            2) Check balance
            3) Money deposite
            4) Money withdraw
            5) Exit
            """) ) 
        if(choice==1):
            self.set_pin()
            self.menu()
        elif(choice==2):
            self.check_balance()
            self.menu()
        elif(choice==3):
            self.deposite()
            self.menu()
        elif(choice==4):
            self.withdraw()
            self.menu()     
        else:
            print("Thank You !")       
                

    def check_pin(self):
        temp = input("Enter the pin")
        if temp!=self.pin:
            return 0
        else:
            return 1    


    def set_pin(self):
        self.pin = input("Enter your pin ")
        print("Pin is successfully set ")


    def check_balance(self):
        if(self.check_pin()==0):
            print("Wrong pin ") 
        else:
            print(f"the balance of your current account is {self.balance}")  


    def deposite(self):
        try:
            if(self.check_pin()==0):
                print("Wrong pin ")
            else:
                temp = int(input("Enter the deposite amount :"))
                self.balance = self.balance + temp
                print(f"your balance is {self.balance}")
        except:
            print("Enter the digit properly !!!")            


    def withdraw(self):
        try:
            if(self.check_pin()==0):
                print("Wrong pin ")
            else:
                temp = int(input("Enter the withdraw amount : "))
                if(temp>self.balance):
                    print("Insaficient Balance .")
                else:
                    self.balance = self.balance - temp
                    print("Withdrawn is successful ")
                    print(f"The current balance is {self.balance}")    
        except:
            print("Enter digit properly !!!")

# %% [markdown]
# ### A class variable is a variable defined inside a class but outside any method, and it is shared by all objects of that class.
# if i want to give serial no to every user of the ATM ... i will not use just "serial_no = 0" variable and just increment it by 1, coz it will create diff "serial_no" for every object and start from 0 ...so have to use class variable

# %% [markdown]
# ### class variable required when the object need something shared

# %%
class ATM:

    ### class variable
    __counter = 1
    def __init__(self):
        self.__pin = ""
        self.__balance = 0
        self.sno = ATM.__counter
        ATM.__counter = ATM.__counter + 1
        #self.menu()
    @staticmethod    
    def get_counter(): ### need no object(self)
        return ATM.__counter
    @staticmethod
    def set_counter(new):
         ### need no object(self)
        if(isinstance(new,str)):
            print("not allowed") 
        else:

            ATM.__counter = new
            print(ATM.__counter)      
    def menu(self):        
        choice = int(input("""
            Enter the option no : 
            1) Set pin
            2) Check balance
            3) Money deposite
            4) Money withdraw
            5) Exit
            """) ) 
        if(choice==1):
            self.set_pin()
            #self.menu()
        elif(choice==2):
            self.check_balance()
            #self.menu()
        elif(choice==3):
            self.deposite()
            #self.menu()
        elif(choice==4):
            self.withdraw()
            #self.menu()     
        else:
            print("Thank You !")       
                

    def check_pin(self):
        temp = input("Enter the pin")
        if temp!=self.__pin:
            return 0
        else:
            return 1    


    def set_pin(self):
        self.__pin = input("Enter your pin ")
        print("Pin is successfully set ")


    def check_balance(self):
        if(self.check_pin()==0):
            print("Wrong pin ") 
        else:
            print(f"the balance of your current account is {self.balance}")  


    def deposite(self):
        try:
            if(self.check_pin()==0):
                print("Wrong pin ")
            else:
                temp = int(input("Enter the deposite amount :"))
                self.__balance = self.__balance + temp
                print(f"your balance is {self.__balance}")
        except:
            print("Enter the digit properly !!!")            


    def withdraw(self):
        try:
            if(self.check_pin()==0):
                print("Wrong pin ")
            else:
                temp = int(input("Enter the withdraw amount : "))
                if(temp>self.__balance):
                    print("Insaficient Balance .")
                else:
                    self.__balance = self.__balance - temp
                    print("Withdrawn is successful ")
                    print(f"The current balance is {self.__balance}")    
        except:
            print("Enter digit properly !!!")

# %%
sbi = ATM()
hdfc = ATM()
bandhan = ATM()

# %%
sbi.get_counter()
# Out:
# 4

# %%
sbi.set_counter(8)
# Out:
# 8

# %%
sbi.set_counter("f")
# Out:
# not allowed

# %%
hdfc.get_counter()
# Out:
# 8

# %% [markdown]
# ### Class Relationships
# ![diagram](class_relationship.png)

# %% [markdown]
# ### aggrigation is a "has a" relation like a customer class have a "has a" relation with address class ... coz every custoner have a address

# %%
class Customer:
    def __init__(self,name,address):
        self.name = name
        self.address = address
class Address:
    def __init__(self,city,pin,state):
        self.city = city
        self.pin = pin
        self.state = state
add = Address("jaipur",123456,"Rajastan")
cust = Customer("muku",add)

print(cust.name)
print(cust.address.city)
# Out:
# muku
# jaipur

# %%
class Customer:
    def __init__(self,name,address):
        self.name = name
        self.address = address

    def change_profile(self,new_name,new_city,new_pin,new_state):
        self.name = new_name
        self.address.change_address(new_city,new_pin,new_state)    
class Address:
    def __init__(self,city,pin,state):
        self.city = city
        self.pin = pin
        self.state = state

    def change_address(self,new_city,new_pin,new_state):
        self.city = new_city
        self.pin = new_pin
        self.state = new_state

add = Address("jaipur",123456,"Rajastan")
cust = Customer("muku",add)

print(cust.name)
print(cust.address.city) ### ***

cust.change_profile("muku","haldia",721635,"WB")
print(cust.name)
print(cust.address.city)
# Out:
# muku
# jaipur
# muku
# haldia

# %% [markdown]
# ### inheritance is "is a" relationship ..like all car class can inharite all features from vehical class ...coz car "is a" vehical

# %% [markdown]
# ### a child class inherite all variables ...methodes ...and constructors from the parent class except the private members ...__private members are not inherited__

# %%
#### inheritance

class User:
    def login(self):
        print("log in successful")
    def password(self):
        print("password created")


class Student(User):
    ### student is a child class of user
    def register(self):
        print("registered")   


student1 = Student()
student1.login()
student1.password()
student1.register()
# Out:
# log in successful
# password created
# registered

# %% [markdown]
# ### if child class dont have any constructor it will call the parent class constructor

# %%
class Phone:
    def __init__(self,name,price):
        print("inside phone constructor")
        self.name= name
        self.price = price

class Apple(Phone):
    pass
apple = Apple(name = "apple",price = 123410)
print(apple.price)
# Out:
# inside phone constructor
# 123410

# %% [markdown]
# ### inherite private attribute

# %%
class Phone:
    def __init__(self,name,price):
    
            print("inside phone constructor")
            self.name= name
            self.__price = price
               

class Apple(Phone):
    pass
apple = Apple(name = "apple",price = 123287)
print(apple.price) ### AttributeError: 'Apple' object has no attribute 'price'  ..best way to use a get_price() methode 
print(apple.name)  ### apple
# Out:
# inside phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 12
#      10     pass
#      11 apple = Apple(name = "apple",price = 123287)
# ---> 12 print(apple.price) ### AttributeError: 'Apple' object has no attribute 'price'
#      13 print(apple.name)  ### apple
#
# AttributeError: 'Apple' object has no attribute 'price'

# %% [markdown]
# ### Polymorphism

# %% [markdown]
# ### Polymorphism means “one thing behaving in many ways.”
# ### In Python, it allows the same function name, method, or operator to work differently depending on the object.

# %%
class Dog:
    def sound(self):
        return "Bark"

class Cat:
    def sound(self):
        return "Meow"

animals = [Dog(), Cat()]

for a in animals:
    print(a.sound())
# Out:
# Bark
# Meow

# %% [markdown]
# ### if child class have ho constructor then its automatiocally run parent constructor but if both have a constructor then child's constructor will run and parent's consdtructor will not  run

# %%
class Parent:
    def __init__(self,num):
        self.num = num

    def get_num(self):
        return self.num    
class Son(Parent):
    def __init__(self,val,num):
        self.val = val        
    def get_val(self):
        return self.val

s = Son(2,4)
s.get_val()
# Out:
# 2

# %%
class Parent:
    def __init__(self,num):
        self.num = num

    def get_num(self):
        return self.num    
class Son(Parent):
    def __init__(self,val,num):
        self.val = val        
    def get_val(self):
        return self.val

s = Son(2,3)
s.get_num()  ## give AttributeError as son have its own contructor so the parent constructor will never run and the num will never initialize
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 14
#      11         return self.val
#      13 s = Son(2,3)
# ---> 14 s.get_num()  ## give AttributeError as son have its own contructor so the parent constructor will never run and the num will never initialize
#
# Cell In[14], line 6, in Parent.get_num(self)
#       5 def get_num(self):
# ----> 6     return self.num
#
# AttributeError: 'Son' object has no attribute 'num'

# %% [markdown]
# ### calling parent class constructor by __super__ keyword

# %%
class Parent:
    def __init__(self,num):
        self.__num = num

    def get_num(self):
        return self.__num    
class Son(Parent):
    def __init__(self,val,num): 
        ### in child class constructor we have to pass all required arguments for child class __init__ function as well as parent class's __init__ function 
        super().__init__(num)  
        self.val = val
    def get_val(self):
        return self.val

s = Son(2,3)
print(s.get_num())
print(s.get_val())
# Out:
# 3
# 2

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("Buying a phone")


class SmartPhone(Phone):
    def buy(self):
        print("Buying a smartphone")
        super().buy()
        ### call bye() of parent class coz , by default when we call s.buy() as s is the object of SmartPhone so it will call its buy() function not parent's buy() fn.


s = SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
class Parent:
    def __init__(self):
        self.num = 100


class Child(Parent):
    def __init__(self):
        super().__init__()
        self.var = 200

    def show(self):
        print(self.num) ## chile can access parent variable by using self from inside the class 
        print(self.var)


son = Child()
son.show()
# Out:
# 100
# 200
